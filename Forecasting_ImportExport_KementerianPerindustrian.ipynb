# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10,6

# %%
dataset = pd.read_excel("data_industri.xlsx")
dataset
# Out:
#                                     DATA EKSPOR IMPOR  Unnamed: 1  \
# 0                       Periode 2000 s/d Oktober 2017         NaN
# 1                                                 NaN         NaN
# 2                                           A. Ekspor         NaN
# 3                                            INDUSTRI     Periode
# 4                                                 NaN        2000
# 5                                                 NaN  Berat (Kg)
# 6                      INDUSTRI ALAT ANGKUTAN LAINNYA   123791375
# 7    INDUSTRI BAHAN KIMIA DAN BARANG DARI BAHAN KIMIA  7305058688
# 8                  INDUSTRI BARANG GALIAN BUKAN LOGAM  9287693297
# 9   INDUSTRI BARANG LOGAM, BUKAN MESIN DAN PERALAT...   287515673
# 10  INDUSTRI FARMASI, PRODUK OBAT KIMIA DAN OBAT T...    14189959
# 11                                  INDUSTRI FURNITUR   787982752
# 12      INDUSTRI KARET, BARANG DARI KARET DAN PLASTIK  1877162602
# ...

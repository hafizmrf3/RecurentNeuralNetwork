# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
# Defaults
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams.update({'font.size': 12})
plt.style.use('ggplot')

# %%
dataset = pd.read_excel("Furniture_DsKemenperin2018 - copy.xlsx", index=False)
dataset
# Out:
#     Tahun        Ekspor  Impor(Kg)
# 0    2000  7.879828e+08    5568524
# 1    2001  7.542638e+08    4935164
# 2    2002  8.392383e+08    8804888
# 3    2003  8.594292e+08   12762356
# 4    2004  8.228902e+08   28033041
# 5    2005  8.620393e+08   45808275
# 6    2006  8.580340e+08   55078034
# 7    2007  8.757853e+08   70643667
# 8    2008  8.096485e+08   73238438
# 9    2009  6.839289e+08   52728695
# 10   2010  7.466868e+08   82226255
# 11   2011  6.287342e+08  111258487
# 12   2012  6.033387e+08  134057054
# 13   2013  5.609862e+08  140247868
# 14   2014  5.615711e+08  135796139
# 15   2015  5.134837e+08  132881260
# 16   2016  4.752410e+08  142603042
# 17   2017  3.824921e+08  129054711

# %%
# Load the data
data = pd.read_excel('Furniture_DsKemenperin2018 - copy.xlsx')
# A bit of pre-processing to make it nicer

# Plot the data
data.plot()
plt.ylabel('Ekspor')
plt.xlabel('Tahun')
plt.show()
